# %%
! python train_yolo.py --network mobilenet1.0 --dataset roughy --gpus 0, --epochs 10\
--val-interval 2 --save-prefix clf-outputs-yolo --no-random-shape --batch-size 16 --warmup-epochs 2\
--warmup-lr 0.0001
# Out:
# [gpu(0)]
# INFO:root:Namespace(amp=False, batch_size=16, data_shape=416, dataset='roughy', epochs=10, gpus='0,', horovod=False, label_smooth=False, log_interval=100, lr=0.001, lr_decay=0.1, lr_decay_epoch='160,180', lr_decay_period=0, lr_mode='step', mixup=False, momentum=0.9, network='mobilenet1.0', no_mixup_epochs=20, no_random_shape=True, no_wd=False, num_samples=368, num_workers=4, resume='', save_interval=10, save_prefix='clf-outputs-yoloyolo3_mobilenet1.0_voc', seed=233, start_epoch=0, syncbn=False, sys_root='/home/ec2-user/SageMaker/csiro-aos-object-detection', train_yr='OPall', val_interval=2, voc_base='VOCportALL', warmup_epochs=2, warmup_lr=0.0001, wd=0.0005)
# INFO:root:Start training from [Epoch 0]
# [20:08:26] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# ...
